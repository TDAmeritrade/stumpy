# %% [markdown]
# $
# \begin{align}
#     D(Q, T[i])^2 &=
#         \sum \limits _{i}
#             \begin{pmatrix}
#                 \frac{T[i]-M_{T[i]}}{\Sigma_{T[i]}}
#                 -
#                 \frac{Q-\mu_Q}{\sigma_Q}
#             \end{pmatrix}^2
#         \\
#     &=
#         \sum \limits _{i}
#             \begin{bmatrix}
#             \begin{pmatrix}
#                 \frac{T[i]-M_{T[i]}}{\Sigma_{T[i]}}
#             \end{pmatrix}^2
#             -
#             2
#             \begin{pmatrix}
#                 \frac{T[i]-M_{T[i]}}{\Sigma_{T[i]}}
#             \end{pmatrix}
#             \begin{pmatrix}
#                 \frac{Q-\mu_Q}{\sigma_Q}
#             \end{pmatrix}
#             +
#             \begin{pmatrix}
#                 \frac{Q-\mu_Q}{\sigma_Q}
#             \end{pmatrix}^2
#             \end{bmatrix}
#         \\
#     &=
#         \sum \limits _{i}
#             \begin{pmatrix}
#                 \frac{T[i]-M_{T[i]}}{\Sigma_{T[i]}}
#             \end{pmatrix}^2
#             -
#         \sum \limits _{i}
#             2
#             \begin{pmatrix}
#                 \frac{T[i]-M_{T[i]}}{\Sigma_{T[i]}}
#             \end{pmatrix}
#             \begin{pmatrix}
#                 \frac{Q-\mu_Q}{\sigma_Q}
#             \end{pmatrix}
#             +
#         \sum \limits _{i}
#             \begin{pmatrix}
#                 \frac{Q-\mu_Q}{\sigma_Q}
#             \end{pmatrix}^2
#         \\
#     &=
#         m
#         -
#         \sum \limits _{i}
#             2
#             \begin{pmatrix}
#                 \frac{T[i]-M_{T[i]}}{\Sigma_{T[i]}}
#             \end{pmatrix}
#             \begin{pmatrix}
#                 \frac{Q-\mu_Q}{\sigma_Q}
#             \end{pmatrix}
#         +
#         m
#         \\
#     &=
#         2m
#         -
#         2
#         \sum \limits _{i}
#             \begin{pmatrix}
#                 \frac{T[i]-M_{T[i]}}{\Sigma_{T[i]}}
#             \end{pmatrix}
#             \begin{pmatrix}
#                 \frac{Q-\mu_Q}{\sigma_Q}
#             \end{pmatrix}
#         \\
#     &=
#         2m
#         \begin{bmatrix}
#             1
#             -
#             \frac{1}{m}
#             \sum \limits _{i}
#                 \begin{pmatrix}
#                     \frac{T[i]-M_{T[i]}}{\Sigma_{T[i]}}
#                 \end{pmatrix}
#                 \begin{pmatrix}
#                     \frac{Q-\mu_Q}{\sigma_Q}
#                 \end{pmatrix}
#         \end{bmatrix}
#         \\
#     &=
#         2m
#         \begin{bmatrix}
#             1
#             -
#             \sum \limits _{i}
#                 \begin{pmatrix}
#                     \frac{
#                         \begin{pmatrix}
#                             T[i]-M_{T[i]}
#                         \end{pmatrix}
#                         \begin{pmatrix}
#                             Q-\mu_Q
#                         \end{pmatrix}
#                     }{
#                         m \sigma_Q \Sigma_{T[i]}
#                     }
#                 \end{pmatrix}
#         \end{bmatrix}
#         \\
#     &=
#         2m
#         \begin{bmatrix}
#         1
#         -
#         \sum \limits _{i}
#             \frac{
#                 T[i]Q
#                 -T[i]\mu_Q
#                 -M_{T[i]}Q
#                 +M_{T[i]}\mu_Q
#             }{
#                 m \sigma_Q \Sigma_{T[i]}
#             }
#         \end{bmatrix}
#         \\
#     &=
#         2m
#         \begin{bmatrix}
#         1
#         -
#         \frac{
#             Q\cdot{T[i]}
#             -
#             \sum \limits _{i}
#                 T[i]\mu_Q
#             -
#             \sum \limits _{i}
#                 \begin{pmatrix}
#                 M_{T[i]}Q
#                 -M_{T[i]}{\mu_Q}
#                 \end{pmatrix}
#         }{
#             m \sigma_Q \Sigma_{T[i]}
#         }
#         \end{bmatrix}
#         \\
#     &=
#         2m
#         \begin{bmatrix}
#             1
#             -
#             \frac{
#                 Q\cdot{T[i]}
#                 -
#                 \sum \limits _{i}
#                     T[i]\mu_Q
#                 -
#                 M_{T[i]}
#                 \sum \limits _{i}
#                     \begin{pmatrix}
#                     Q-{\mu_Q}
#                     \end{pmatrix}
#             }{
#                 m \sigma_Q \Sigma_{T[i]}
#             }
#         \end{bmatrix}
#         \\
#     &=
#         2m
#         \begin{bmatrix}
#             1
#             -
#             \frac{
#                 Q\cdot{T[i]}
#                 -
#                 \mu_Q
#                 \sum \limits _{i}
#                     T[i]
#                 -
#                 0
#             }{
#                 m \sigma_Q \Sigma_{T[i]}
#             }
#         \end{bmatrix}
#         \\
#     &=
#         2m
#         \begin{bmatrix}
#             1
#             -
#             \frac{
#                 Q\cdot{T[i]}
#                 -
#                 \mu_Q
#                 \sum \limits _{i}
#                     T[i]
#             }{
#                 m \sigma_Q \Sigma_{T[i]}
#             }
#         \end{bmatrix}
#         \\
#     &=
#         2m
#         \begin{bmatrix}
#             1
#             -
#             \frac{
#                 Q\cdot{T[i]}
#                 -
#                 \mu_{Q}m
#                 \sum \limits _{i}
#                     \frac{T[i]}{m}
#             }{
#                 m \sigma_Q \Sigma_{T[i]}
#             }
#         \end{bmatrix}
#         \\
#     &=
#         2m
#         \begin{pmatrix}
#             1
#             -
#             \frac{
#                 Q\cdot{T[i]}
#                 -
#                 m\mu_{Q}M_{T[i]}
#             }{
#                 m \sigma_Q \Sigma_{T[i]}
#             }
#         \end{pmatrix}
#         \\
# \end{align}
# $
